# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter("ignore")

# %%
result_df = pd.read_csv('./f1-data/results.csv')
stats_df = pd.read_csv('./f1-data/status.csv')
drivers_df = pd.read_csv('./f1-data/drivers.csv')
races_df = pd.read_csv('./f1-data/races.csv')
constructor_df = pd.read_csv('./f1-data/constructors.csv')
driver_standings_df = pd.read_csv('./f1-data/driver_standings.csv')
qualifying_df = pd.read_csv('./f1-data/qualifying.csv')
pd.get_option("display.max_columns",None)
# Out:
# 20

# %%
con1 = pd.merge(result_df, qualifying_df, on = ['raceId', 'driverId'], copy = False, suffixes = ['_res', '_q'])
con2 = pd.merge(con1, races_df, on ='raceId', copy = False, suffixes = ['_con1', '_race'])
con3 = pd.merge(con2, drivers_df, on = 'driverId', copy = False, suffixes = ['_con2', '_driv'])
con4 = pd.merge(con3, driver_standings_df, on = ['driverId', 'raceId'], 
                copy = False, suffixes = ['_con3', '_driv_s'])

# %%
con4.columns
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId_res', 'number_res',
#        'grid', 'position_res', 'positionText_con3', 'positionOrder',
#        'points_con3', 'laps', 'time_con1', 'milliseconds', 'fastestLap',
#        'rank', 'fastestLapTime', 'fastestLapSpeed', 'statusId', 'qualifyId',
#        'constructorId_q', 'number_q', 'position_q', 'q1', 'q2', 'q3', 'year',
#        'round', 'circuitId', 'name', 'date', 'time_race', 'url_con2',
#        'driverRef', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'url_driv', 'driverStandingsId', 'points_driv_s',
#        'position', 'positionText_driv_s', 'wins'],
#       dtype='object')

# %%
con5 = pd.merge(con4, constructor_df, left_on ='constructorId_res', 
                right_on = 'constructorId', copy = False, suffixes = ['_con4', '_const'])
df = pd.merge(con5, stats_df, on ='statusId', copy = False, suffixes = ['_con5', '_stat'])
pd.get_option("display.max_columns",None)
df.head()
# Out:
#    resultId  raceId  driverId  constructorId_res number_res  grid  \
# 0         1      18         1                  1         22     1
# 1        27      19         1                  1         22     9
# 2        69      21         1                  1         22     5
# 3        90      22         1                  1         22     3
# 4       109      23         1                  1         22     3
#
#   position_res positionText_con3  positionOrder  points_con3    ...     \
# 0            1                 1              1         10.0    ...
# 1            5                 5              5          4.0    ...
# 2            3                 3              3          6.0    ...
# 3            2                 2              2          8.0    ...
# 4            1                 1              1         10.0    ...
#
#    points_driv_s position positionText_driv_s wins constructorId  \
# 0           10.0        1                   1    1             1
# 1           14.0        1                   1    1             1
# 2           20.0        2                   2    1             1
# 3           28.0        3                   3    1             1
# 4           38.0        1                   1    2             1
#
#   constructorRef name_const  nationality_const  \
# 0        mclaren    McLaren            British
# 1        mclaren    McLaren            British
# 2        mclaren    McLaren            British
# 3        mclaren    McLaren            British
# 4        mclaren    McLaren            British
#
#                                     url    status
# 0  http://en.wikipedia.org/wiki/McLaren  Finished
# 1  http://en.wikipedia.org/wiki/McLaren  Finished
# 2  http://en.wikipedia.org/wiki/McLaren  Finished
# 3  http://en.wikipedia.org/wiki/McLaren  Finished
# 4  http://en.wikipedia.org/wiki/McLaren  Finished
#
# [5 rows x 51 columns]

# %%
df.shape
# Out:
# (8954, 51)

# %%
df = df.drop(['raceId', 'constructorId_res', 'number_res', 'position_res', 'positionText_con3',
              'url_con2', 'url_driv', 'driverStandingsId'],1)

# %%
df = df.drop(['constructorId_q', 'constructorId', 'constructorRef', 'nationality_con4',
             'positionOrder', 'positionText_driv_s', 'time_con1', 'rank', 'statusId', 'resultId', 
             'driverId', 'qualifyId', 'number_q', 'round', 'circuitId', 'time_race', 'driverRef',
             'number', 'code'], 1)

# %%
df = df.drop(['grid', 'wins'], 1)

col_name = {'position_q':'starting_pos', 'milliseconds':'timetaken_in_millisec', 'fastestLapSpeed':'max_speed',
            'points_driv_s':'cumulative_points_including_this_race', 'name_const':'company', 'nationality_const':'nationality',
            'year':'race_year', 'name_con4':'race_track', 'position':'final_pos', 'points_con3':'points_from_this_race'}

df.rename(columns=col_name,inplace=True)
df.head()
# Out:
#    points_from_this_race  laps timetaken_in_millisec fastestLap  \
# 0                   10.0    58               5690616         39
# 1                    4.0    56               5525103         53
# 2                    6.0    66               5903238         20
# 3                    8.0    58               5213230         31
# 4                   10.0    76               7242742         71
#
#   fastestLapTime max_speed  starting_pos        q1        q2        q3  \
# 0       1:27.452   218.300             1  1:26.572  1:25.187  1:26.714
# 1       1:35.462   209.033             4  1:35.392  1:34.627  1:36.709
# 2       1:22.017   204.323             5  1:21.366  1:20.825  1:22.096
# 3       1:26.529   222.085             3  1:26.192  1:26.477  1:27.923
# 4       1:18.510   153.152             3  1:15.582  1:15.322  1:15.839
#
#      ...         date forename   surname         dob  \
# 0    ...     16/03/08    Lewis  Hamilton  1985-01-07
# 1    ...     23/03/08    Lewis  Hamilton  1985-01-07
# 2    ...     27/04/08    Lewis  Hamilton  1985-01-07
# 3    ...     11/05/08    Lewis  Hamilton  1985-01-07
# 4    ...     25/05/08    Lewis  Hamilton  1985-01-07
#
#   cumulative_points_including_this_race final_pos  company  nationality  \
# 0                                  10.0         1  McLaren      British
# 1                                  14.0         1  McLaren      British
# 2                                  20.0         2  McLaren      British
# 3                                  28.0         3  McLaren      British
# 4                                  38.0         1  McLaren      British
#
#                                     url    status
# 0  http://en.wikipedia.org/wiki/McLaren  Finished
# 1  http://en.wikipedia.org/wiki/McLaren  Finished
# 2  http://en.wikipedia.org/wiki/McLaren  Finished
# 3  http://en.wikipedia.org/wiki/McLaren  Finished
# 4  http://en.wikipedia.org/wiki/McLaren  Finished
#
# [5 rows x 22 columns]

# %%
df.head(1).T
# Out:
#                                                                           0
# points_from_this_race                                                    10
# laps                                                                     58
# timetaken_in_millisec                                               5690616
# fastestLap                                                               39
# fastestLapTime                                                     1:27.452
# max_speed                                                           218.300
# starting_pos                                                              1
# q1                                                                 1:26.572
# q2                                                                 1:25.187
# q3                                                                 1:26.714
# race_year                                                              2008
# race_track                                            Australian Grand Prix
# date                                                               16/03/08
# forename                                                              Lewis
# surname                                                            Hamilton
# dob                                                              1985-01-07
# cumulative_points_including_this_race                                    10
# final_pos                                                                 1
# company                                                             McLaren
# nationality                                                         British
# url                                    http://en.wikipedia.org/wiki/McLaren
# status                                                             Finished

# %%
df.head(100)
# Out:
#     points_from_this_race  laps timetaken_in_millisec fastestLap  \
# 0                    10.0    58               5690616         39
# 1                     4.0    56               5525103         53
# 2                     6.0    66               5903238         20
# 3                     8.0    58               5213230         31
# 4                    10.0    76               7242742         71
# 5                     0.0    70               5564783         40
# 6                    10.0    60               5949440         16
# 7                    10.0    67               5480874         17
# 8                     4.0    70               5870115         15
# 9                     8.0    57               5737950         16
# 10                    6.0    44               4989933         20
# 11                    2.0    53               5237406         52
# 12                    6.0    61               7042221         14
# 13                    0.0    67               5500792         65
# 14                   10.0    56               5517403         13
# 15                    4.0    71               5690342         31
# 16                    6.0    58               5147365         20
# 17                    8.0    56               5552487         22
# 18                    8.0    57               5609875         18
# 19                    8.0    65               5503020         20
# 20                    8.0    78               6033424         28
# 21                   10.0    70               6251292         37
# 22                   10.0    73               5469965         20
# 23                    6.0    70               5486353         39
# 24                    6.0    59               4942447         11
# 25                   10.0    70               5752991         13
# 26                    4.0    58               5247246         17
# 27                    8.0    53               4723868         17
# 28                    5.0    44               4862681         41
# 29                   10.0    67               7234579         27
# ..                    ...   ...                   ...        ...
# 70                   15.0    58               5653640         57
# 71                   15.0    56               9906403         50
# 72                   15.0    56               5812941         40
# 73                    4.0    57               5769974         38
# 74                    4.0    66               6027285         50
# 75                   10.0    78               6370658         46
# 76                   25.0    70               5549586         59
# 77                    4.0    52               5147751         44
# 78                   25.0    69               6065503         65
# 79                   25.0    53               4781221         52
# 80                   10.0    53               5382732         45
# 81                    1.0    55               5868343         49
# 82                   12.0    60               5484653         58
# 83                   25.0    56               5755269         55
# 84                    8.0    58               5136012         20
# 85                   10.0    56               5534930         42
# 86                    4.0    57               5621941         46
# 87                    6.0    65               5513686         17
# 88                   10.0    78               6029329         44
# 89                    2.0    70               6273228         46
# 90                    8.0    73               5471465         21
# 91                    2.0    70               5510716         36
# 92                    8.0    59               4905533         35
# 93                   10.0    60               7586358         35
# 94                    5.0    70               5797849         49
# 95                    6.0    58               5228342         39
# 96                   10.0    53               4717806         15
# 97                    6.0    44               4853409         44
# 98                    8.0    56               5888201         54
# 99                    6.0    71               5352289         59
#
#    fastestLapTime max_speed  starting_pos        q1        q2        q3  \
# 0        1:27.452   218.300             1  1:26.572  1:25.187  1:26.714
# 1        1:35.462   209.033             4  1:35.392  1:34.627  1:36.709
# 2        1:22.017   204.323             5  1:21.366  1:20.825  1:22.096
# 3        1:26.529   222.085             3  1:26.192  1:26.477  1:27.923
# 4        1:18.510   153.152             3  1:15.582  1:15.322  1:15.839
# 5        1:17.453   205.022             3  1:15.634  1:15.293  1:16.693
# 6        1:32.817   199.398             4  1:20.288  1:19.537  1:21.835
# 7        1:16.039   216.552             1  1:15.218  1:14.603  1:15.666
# 8        1:21.493   193.533             1  1:19.376  1:19.473  1:20.899
# 9        1:38.884   197.285             2  1:38.464  1:37.954  1:39.199
# 10       1:48.135   233.175             1  1:46.887  1:46.088  1:47.338
# 11       1:29.721   232.440            15  1:35.394  1:39.265        \N
# 12       1:46.072   171.969             2  1:44.501  1:44.932  1:45.465
# 13       1:19.560   206.470             1  1:18.071  1:17.462  1:18.404
# 14       1:36.325   203.722             1  1:35.566  1:34.947  1:36.303
# 15       1:14.159   209.177             4  1:12.213  1:11.856  1:12.830
# 16       1:26.351   221.083             4  1:26.674  1:25.577  1:26.755
# 17       1:36.701   206.355             4  1:35.028  1:34.650  1:36.045
# 18       1:34.270   206.674             2  1:32.580  1:31.752  1:32.935
# 19       1:22.876   202.205             4  1:21.120  1:20.713  1:21.785
# 20       1:15.372   159.528             2  1:15.685  1:15.479  1:15.905
# 21       1:16.494   205.239             1  1:16.576  1:15.486  1:15.707
# 22       1:13.222   206.101             1  1:12.563  1:12.065  1:12.331
# 23       1:16.587   207.340             2  1:14.805  1:14.795  1:15.104
# 24       1:21.675   226.600             1  1:19.885  1:19.400  1:19.997
# 25       1:20.171   196.724             2  1:19.570  1:19.301  1:19.781
# 26       1:27.963   218.464             2  1:27.513  1:26.936  1:27.373
# 27       1:22.936   251.456             2  1:21.956  1:21.746  1:22.034
# 28       1:48.215   233.002             4  1:46.437  1:45.132  1:46.406
# 29       1:28.193   186.259             1  1:25.489  1:24.753  1:25.368
# ..            ...       ...           ...       ...       ...       ...
# 70       1:29.538   213.214             1  1:26.800  1:25.626  1:24.922
# 71       1:41.539   196.523             1  1:37.813  1:37.106  1:36.219
# 72       1:40.530   195.201             2  1:36.763  1:35.902  1:35.626
# 73       1:37.733   199.351             2  1:34.813  1:33.209  1:32.520
# 74       1:28.918   188.465             1  1:22.583  1:22.465  1:21.707
# 75       1:18.806   152.577             4  1:16.063  1:15.166  1:14.583
# 76       1:17.020   203.837             2  1:14.891  1:14.371  1:14.087
# 77       1:36.173   220.515             8  1:47.433  1:54.897  1:53.543
# 78       1:25.677   184.082             1  1:21.794  1:21.060  1:20.953
# 79       1:28.427   235.841             1  1:24.211  1:24.394  1:24.010
# 80       1:37.760   213.842             9  1:33.061  1:32.121  1:32.327
# 81       1:42.721   196.785             3  1:39.180  1:38.000  1:37.469
# 82       1:28.944   207.433             3  1:26.516  1:25.816  1:25.544
# 83       1:39.709   199.047             2  1:37.058  1:36.795  1:35.766
# 84       1:26.314   221.178             2  1:26.697  1:25.326  1:26.493
# 85       1:36.861   206.014             2  1:34.942  1:34.057  1:35.310
# 86       1:34.420   206.346             4  1:33.049  1:32.214  1:33.192
# 87       1:22.966   201.986             2  1:21.609  1:20.797  1:21.451
# 88       1:15.284   159.715             1  1:16.059  1:15.431  1:15.726
# 89       1:16.367   205.580             2  1:16.562  1:15.522  1:16.163
# 90       1:13.257   206.003             2  1:12.416  1:11.926  1:12.500
# 91       1:16.495   207.590            10  1:15.322  1:15.084        \N
# 92       1:21.117   228.159             3  1:19.330  1:19.152  1:20.147
# 93       1:33.231   198.783             2  1:31.074  1:30.983  1:31.741
# 94       1:20.324   196.349             1  1:20.425  1:19.661  1:19.674
# 95       1:28.070   218.199             4  1:27.328  1:26.841  1:27.574
# 96       1:22.871   251.653             1  1:21.718  1:21.356  1:21.997
# 97       1:48.182   233.073             3  1:46.058  1:45.442  1:46.091
# 98       1:37.991   200.259             4  1:35.809  1:35.845  1:36.576
# 99       1:13.150   212.062             4  1:12.895  1:12.637  1:12.356
#
#       ...         date  forename   surname         dob  \
# 0     ...     16/03/08     Lewis  Hamilton  1985-01-07
# 1     ...     23/03/08     Lewis  Hamilton  1985-01-07
# 2     ...     27/04/08     Lewis  Hamilton  1985-01-07
# 3     ...     11/05/08     Lewis  Hamilton  1985-01-07
# 4     ...     25/05/08     Lewis  Hamilton  1985-01-07
# 5     ...     22/06/08     Lewis  Hamilton  1985-01-07
# 6     ...     06/07/08     Lewis  Hamilton  1985-01-07
# 7     ...     20/07/08     Lewis  Hamilton  1985-01-07
# 8     ...     03/08/08     Lewis  Hamilton  1985-01-07
# 9     ...     24/08/08     Lewis  Hamilton  1985-01-07
# 10    ...     07/09/08     Lewis  Hamilton  1985-01-07
# 11    ...     14/09/08     Lewis  Hamilton  1985-01-07
# 12    ...     28/09/08     Lewis  Hamilton  1985-01-07
# 13    ...     12/10/08     Lewis  Hamilton  1985-01-07
# 14    ...     19/10/08     Lewis  Hamilton  1985-01-07
# 15    ...     02/11/08     Lewis  Hamilton  1985-01-07
# 16    ...     18/03/07     Lewis  Hamilton  1985-01-07
# 17    ...     08/04/07     Lewis  Hamilton  1985-01-07
# 18    ...     15/04/07     Lewis  Hamilton  1985-01-07
# 19    ...     13/05/07     Lewis  Hamilton  1985-01-07
# 20    ...     27/05/07     Lewis  Hamilton  1985-01-07
# 21    ...     10/06/07     Lewis  Hamilton  1985-01-07
# 22    ...     17/06/07     Lewis  Hamilton  1985-01-07
# 23    ...     01/07/07     Lewis  Hamilton  1985-01-07
# 24    ...     08/07/07     Lewis  Hamilton  1985-01-07
# 25    ...     05/08/07     Lewis  Hamilton  1985-01-07
# 26    ...     26/08/07     Lewis  Hamilton  1985-01-07
# 27    ...     09/09/07     Lewis  Hamilton  1985-01-07
# 28    ...     16/09/07     Lewis  Hamilton  1985-01-07
# 29    ...     30/09/07     Lewis  Hamilton  1985-01-07
# ..    ...          ...       ...       ...         ...
# 70    ...     18/03/12     Lewis  Hamilton  1985-01-07
# 71    ...     25/03/12     Lewis  Hamilton  1985-01-07
# 72    ...     15/04/12     Lewis  Hamilton  1985-01-07
# 73    ...     22/04/12     Lewis  Hamilton  1985-01-07
# 74    ...     13/05/12     Lewis  Hamilton  1985-01-07
# 75    ...     27/05/12     Lewis  Hamilton  1985-01-07
# 76    ...     10/06/12     Lewis  Hamilton  1985-01-07
# 77    ...     08/07/12     Lewis  Hamilton  1985-01-07
# 78    ...     29/07/12     Lewis  Hamilton  1985-01-07
# 79    ...     09/09/12     Lewis  Hamilton  1985-01-07
# 80    ...     07/10/12     Lewis  Hamilton  1985-01-07
# 81    ...     14/10/12     Lewis  Hamilton  1985-01-07
# 82    ...     28/10/12     Lewis  Hamilton  1985-01-07
# 83    ...     18/11/12     Lewis  Hamilton  1985-01-07
# 84    ...     18/03/07  Fernando    Alonso  1981-07-29
# 85    ...     08/04/07  Fernando    Alonso  1981-07-29
# 86    ...     15/04/07  Fernando    Alonso  1981-07-29
# 87    ...     13/05/07  Fernando    Alonso  1981-07-29
# 88    ...     27/05/07  Fernando    Alonso  1981-07-29
# 89    ...     10/06/07  Fernando    Alonso  1981-07-29
# 90    ...     17/06/07  Fernando    Alonso  1981-07-29
# 91    ...     01/07/07  Fernando    Alonso  1981-07-29
# 92    ...     08/07/07  Fernando    Alonso  1981-07-29
# 93    ...     22/07/07  Fernando    Alonso  1981-07-29
# 94    ...     05/08/07  Fernando    Alonso  1981-07-29
# 95    ...     26/08/07  Fernando    Alonso  1981-07-29
# 96    ...     09/09/07  Fernando    Alonso  1981-07-29
# 97    ...     16/09/07  Fernando    Alonso  1981-07-29
# 98    ...     07/10/07  Fernando    Alonso  1981-07-29
# 99    ...     21/10/07  Fernando    Alonso  1981-07-29
#
#    cumulative_points_including_this_race final_pos  company  nationality  \
# 0                                   10.0         1  McLaren      British
# 1                                   14.0         1  McLaren      British
# 2                                   20.0         2  McLaren      British
# 3                                   28.0         3  McLaren      British
# 4                                   38.0         1  McLaren      British
# 5                                   38.0         4  McLaren      British
# 6                                   48.0         1  McLaren      British
# 7                                   58.0         1  McLaren      British
# 8                                   62.0         1  McLaren      British
# 9                                   70.0         1  McLaren      British
# 10                                  76.0         1  McLaren      British
# 11                                  78.0         1  McLaren      British
# 12                                  84.0         1  McLaren      British
# 13                                  84.0         1  McLaren      British
# 14                                  94.0         1  McLaren      British
# 15                                  98.0         1  McLaren      British
# 16                                   6.0         3  McLaren      British
# 17                                  14.0         3  McLaren      British
# 18                                  22.0         3  McLaren      British
# 19                                  30.0         1  McLaren      British
# 20                                  38.0         2  McLaren      British
# 21                                  48.0         1  McLaren      British
# 22                                  58.0         1  McLaren      British
# 23                                  64.0         1  McLaren      British
# 24                                  70.0         1  McLaren      British
# 25                                  80.0         1  McLaren      British
# 26                                  84.0         1  McLaren      British
# 27                                  92.0         1  McLaren      British
# 28                                  97.0         1  McLaren      British
# 29                                 107.0         1  McLaren      British
# ..                                   ...       ...      ...          ...
# 70                                  15.0         3  McLaren      British
# 71                                  30.0         2  McLaren      British
# 72                                  45.0         1  McLaren      British
# 73                                  49.0         2  McLaren      British
# 74                                  53.0         3  McLaren      British
# 75                                  63.0         4  McLaren      British
# 76                                  88.0         1  McLaren      British
# 77                                  92.0         4  McLaren      British
# 78                                 117.0         4  McLaren      British
# 79                                 142.0         2  McLaren      British
# 80                                 152.0         4  McLaren      British
# 81                                 153.0         4  McLaren      British
# 82                                 165.0         5  McLaren      British
# 83                                 190.0         4  McLaren      British
# 84                                   8.0         2  McLaren      British
# 85                                  18.0         1  McLaren      British
# 86                                  22.0         1  McLaren      British
# 87                                  28.0         2  McLaren      British
# 88                                  38.0         1  McLaren      British
# 89                                  40.0         2  McLaren      British
# 90                                  48.0         2  McLaren      British
# 91                                  50.0         2  McLaren      British
# 92                                  58.0         2  McLaren      British
# 93                                  68.0         2  McLaren      British
# 94                                  73.0         2  McLaren      British
# 95                                  79.0         2  McLaren      British
# 96                                  89.0         2  McLaren      British
# 97                                  95.0         2  McLaren      British
# 98                                 103.0         2  McLaren      British
# 99                                 109.0         3  McLaren      British
#
#                                      url    status
# 0   http://en.wikipedia.org/wiki/McLaren  Finished
# 1   http://en.wikipedia.org/wiki/McLaren  Finished
# 2   http://en.wikipedia.org/wiki/McLaren  Finished
# 3   http://en.wikipedia.org/wiki/McLaren  Finished
# 4   http://en.wikipedia.org/wiki/McLaren  Finished
# 5   http://en.wikipedia.org/wiki/McLaren  Finished
# 6   http://en.wikipedia.org/wiki/McLaren  Finished
# 7   http://en.wikipedia.org/wiki/McLaren  Finished
# 8   http://en.wikipedia.org/wiki/McLaren  Finished
# 9   http://en.wikipedia.org/wiki/McLaren  Finished
# 10  http://en.wikipedia.org/wiki/McLaren  Finished
# 11  http://en.wikipedia.org/wiki/McLaren  Finished
# 12  http://en.wikipedia.org/wiki/McLaren  Finished
# 13  http://en.wikipedia.org/wiki/McLaren  Finished
# 14  http://en.wikipedia.org/wiki/McLaren  Finished
# 15  http://en.wikipedia.org/wiki/McLaren  Finished
# 16  http://en.wikipedia.org/wiki/McLaren  Finished
# 17  http://en.wikipedia.org/wiki/McLaren  Finished
# 18  http://en.wikipedia.org/wiki/McLaren  Finished
# 19  http://en.wikipedia.org/wiki/McLaren  Finished
# 20  http://en.wikipedia.org/wiki/McLaren  Finished
# 21  http://en.wikipedia.org/wiki/McLaren  Finished
# 22  http://en.wikipedia.org/wiki/McLaren  Finished
# 23  http://en.wikipedia.org/wiki/McLaren  Finished
# 24  http://en.wikipedia.org/wiki/McLaren  Finished
# 25  http://en.wikipedia.org/wiki/McLaren  Finished
# 26  http://en.wikipedia.org/wiki/McLaren  Finished
# 27  http://en.wikipedia.org/wiki/McLaren  Finished
# 28  http://en.wikipedia.org/wiki/McLaren  Finished
# 29  http://en.wikipedia.org/wiki/McLaren  Finished
# ..                                   ...       ...
# 70  http://en.wikipedia.org/wiki/McLaren  Finished
# 71  http://en.wikipedia.org/wiki/McLaren  Finished
# 72  http://en.wikipedia.org/wiki/McLaren  Finished
# 73  http://en.wikipedia.org/wiki/McLaren  Finished
# 74  http://en.wikipedia.org/wiki/McLaren  Finished
# 75  http://en.wikipedia.org/wiki/McLaren  Finished
# 76  http://en.wikipedia.org/wiki/McLaren  Finished
# 77  http://en.wikipedia.org/wiki/McLaren  Finished
# 78  http://en.wikipedia.org/wiki/McLaren  Finished
# 79  http://en.wikipedia.org/wiki/McLaren  Finished
# 80  http://en.wikipedia.org/wiki/McLaren  Finished
# 81  http://en.wikipedia.org/wiki/McLaren  Finished
# 82  http://en.wikipedia.org/wiki/McLaren  Finished
# 83  http://en.wikipedia.org/wiki/McLaren  Finished
# 84  http://en.wikipedia.org/wiki/McLaren  Finished
# 85  http://en.wikipedia.org/wiki/McLaren  Finished
# 86  http://en.wikipedia.org/wiki/McLaren  Finished
# 87  http://en.wikipedia.org/wiki/McLaren  Finished
# 88  http://en.wikipedia.org/wiki/McLaren  Finished
# 89  http://en.wikipedia.org/wiki/McLaren  Finished
# 90  http://en.wikipedia.org/wiki/McLaren  Finished
# 91  http://en.wikipedia.org/wiki/McLaren  Finished
# 92  http://en.wikipedia.org/wiki/McLaren  Finished
# 93  http://en.wikipedia.org/wiki/McLaren  Finished
# 94  http://en.wikipedia.org/wiki/McLaren  Finished
# 95  http://en.wikipedia.org/wiki/McLaren  Finished
# 96  http://en.wikipedia.org/wiki/McLaren  Finished
# 97  http://en.wikipedia.org/wiki/McLaren  Finished
# 98  http://en.wikipedia.org/wiki/McLaren  Finished
# 99  http://en.wikipedia.org/wiki/McLaren  Finished
#
# [100 rows x 22 columns]

# %%
# df.to_csv('./cleaned-data.csv', index = False)

# %%
df['driver_name'] = df['forename']+' '+df['surname']
df = df.drop(['forename','surname'],1)
df['dob'] = pd.to_datetime(df['dob'])
df['date'] = pd.to_datetime(df['date'])
from datetime import datetime
dates = datetime.today()-df['dob']
age = dates.dt.days/365
df['age'] = round(age)

# %%
df['q1'] = pd.to_datetime(df['q1'], format='%M:%S.%f', errors='coerce')
df['q1'] = df.q1.dt.minute*60 + df.q1.dt.second 

df['q2'] = pd.to_datetime(df['q2'], format='%M:%S.%f', errors='coerce')
df['q2'] = df.q2.dt.minute*60 + df.q2.dt.second 

df['q3'] = pd.to_datetime(df['q3'], format='%M:%S.%f', errors='coerce')
df['q3'] = df.q3.dt.minute*60 + df.q3.dt.second

df['fastestLapTime'] = pd.to_datetime(df['fastestLapTime'], format='%M:%S.%f', errors='coerce')
df['fastestLapTime'] = df.fastestLapTime.dt.minute*60 + df.fastestLapTime.dt.second

# %%
df.head()
# Out:
#    points_from_this_race  laps timetaken_in_millisec fastestLap  \
# 0                   10.0    58               5690616         39
# 1                    4.0    56               5525103         53
# 2                    6.0    66               5903238         20
# 3                    8.0    58               5213230         31
# 4                   10.0    76               7242742         71
#
#    fastestLapTime max_speed  starting_pos    q1    q2    q3  ...        date  \
# 0            87.0   218.300             1  86.0  85.0  86.0  ...  2008-03-16
# 1            95.0   209.033             4  95.0  94.0  96.0  ...  2008-03-23
# 2            82.0   204.323             5  81.0  80.0  82.0  ...  2008-04-27
# 3            86.0   222.085             3  86.0  86.0  87.0  ...  2008-11-05
# 4            78.0   153.152             3  75.0  75.0  75.0  ...  2008-05-25
#
#          dob cumulative_points_including_this_race final_pos  company  \
# 0 1985-01-07                                  10.0         1  McLaren
# 1 1985-01-07                                  14.0         1  McLaren
# 2 1985-01-07                                  20.0         2  McLaren
# 3 1985-01-07                                  28.0         3  McLaren
# 4 1985-01-07                                  38.0         1  McLaren
#
#    nationality                                   url    status  \
# 0      British  http://en.wikipedia.org/wiki/McLaren  Finished
# 1      British  http://en.wikipedia.org/wiki/McLaren  Finished
# 2      British  http://en.wikipedia.org/wiki/McLaren  Finished
# 3      British  http://en.wikipedia.org/wiki/McLaren  Finished
# 4      British  http://en.wikipedia.org/wiki/McLaren  Finished
#
#       driver_name   age
# 0  Lewis Hamilton  37.0
# 1  Lewis Hamilton  37.0
# 2  Lewis Hamilton  37.0
# 3  Lewis Hamilton  37.0
# 4  Lewis Hamilton  37.0
#
# [5 rows x 22 columns]

# %%
#df['q1'][0].time()
#res = s.dt.strftime("%Y-%m-%d %H:%M:%S.%f")

# %%
#df['q1'].dt.strftime("%M:%S.%f")

# %%
df = df.drop(['url'], 1)

l = ['timetaken_in_millisec','fastestLap','max_speed']
for i in l:
    df[i] = pd.to_numeric(df[i],errors='coerce')

# %%
df.head(1).T
# Out:
#                                                            0
# points_from_this_race                                     10
# laps                                                      58
# timetaken_in_millisec                            5.69062e+06
# fastestLap                                                39
# fastestLapTime                                            87
# max_speed                                              218.3
# starting_pos                                               1
# q1                                                        86
# q2                                                        85
# q3                                                        86
# race_year                                               2008
# race_track                             Australian Grand Prix
# date                                     2008-03-16 00:00:00
# dob                                      1985-01-07 00:00:00
# cumulative_points_including_this_race                     10
# final_pos                                                  1
# company                                              McLaren
# nationality                                          British
# status                                              Finished
# driver_name                                   Lewis Hamilton
# age                                                       37

# %%
df.dtypes
# Out:
# points_from_this_race                           float64
# laps                                              int64
# timetaken_in_millisec                           float64
# fastestLap                                      float64
# fastestLapTime                                  float64
# max_speed                                       float64
# starting_pos                                      int64
# q1                                              float64
# q2                                              float64
# q3                                              float64
# race_year                                         int64
# race_track                                       object
# date                                     datetime64[ns]
# dob                                      datetime64[ns]
# cumulative_points_including_this_race           float64
# final_pos                                         int64
# company                                          object
# nationality                                      object
# status                                           object
# driver_name                                      object
# age                                             float64
# dtype: object

# %%
df.isnull().sum() / len(df) * 100
# Out:
# points_from_this_race                     0.000000
# laps                                      0.000000
# timetaken_in_millisec                    56.622738
# fastestLap                               22.481572
# fastestLapTime                           22.481572
# max_speed                                22.481572
# starting_pos                              0.000000
# q1                                        1.563547
# q2                                       45.722582
# q3                                       66.651776
# race_year                                 0.000000
# race_track                                0.000000
# date                                      0.000000
# dob                                       0.000000
# cumulative_points_including_this_race     0.000000
# final_pos                                 0.000000
# company                                   0.000000
# nationality                               0.000000
# status                                    0.000000
# driver_name                               0.000000
# age                                       0.000000
# dtype: float64

# %%
df.to_csv('./cleaned-data.csv', index = False)

# %%
df.head()
# Out:
#    points_from_this_race  laps  timetaken_in_millisec  fastestLap  \
# 0                   10.0    58              5690616.0        39.0
# 1                    4.0    56              5525103.0        53.0
# 2                    6.0    66              5903238.0        20.0
# 3                    8.0    58              5213230.0        31.0
# 4                   10.0    76              7242742.0        71.0
#
#    fastestLapTime  max_speed  starting_pos    q1    q2    q3  ...   \
# 0            87.0    218.300             1  86.0  85.0  86.0  ...
# 1            95.0    209.033             4  95.0  94.0  96.0  ...
# 2            82.0    204.323             5  81.0  80.0  82.0  ...
# 3            86.0    222.085             3  86.0  86.0  87.0  ...
# 4            78.0    153.152             3  75.0  75.0  75.0  ...
#
#               race_track       date        dob  \
# 0  Australian Grand Prix 2008-03-16 1985-01-07
# 1   Malaysian Grand Prix 2008-03-23 1985-01-07
# 2     Spanish Grand Prix 2008-04-27 1985-01-07
# 3     Turkish Grand Prix 2008-11-05 1985-01-07
# 4      Monaco Grand Prix 2008-05-25 1985-01-07
#
#   cumulative_points_including_this_race  final_pos  company nationality  \
# 0                                  10.0          1  McLaren     British
# 1                                  14.0          1  McLaren     British
# 2                                  20.0          2  McLaren     British
# 3                                  28.0          3  McLaren     British
# 4                                  38.0          1  McLaren     British
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  37.0
# 1  Finished  Lewis Hamilton  37.0
# 2  Finished  Lewis Hamilton  37.0
# 3  Finished  Lewis Hamilton  37.0
# 4  Finished  Lewis Hamilton  37.0
#
# [5 rows x 21 columns]
